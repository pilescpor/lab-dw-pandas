# %% [markdown]
# In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# The data includes information such as customer ID, state, gender, education, income, and other variables that can be used to perform various analyses.
#
# Throughout the lab, we will be using the pandas library in Python to manipulate and analyze the data. Pandas is a powerful library that provides various data manipulation and analysis tools, including the ability to load and manipulate data from a variety of sources, including CSV files.

# %% [markdown]
# # Lab | Pandas

# %% [markdown]
# ### Data Description
#
# - Customer - Customer ID
#
# - ST - State where customers live
#
# - Gender - Gender of the customer
#
# - Education - Background education of customers
#
# - Customer Lifetime Value - Customer lifetime value(CLV) is the total revenue the client will derive from their entire relationship with a customer. In other words, is the predicted or calculated value of a customer over their entire duration as a policyholder with the insurance company. It is an estimation of the net profit that the insurance company expects to generate from a customer throughout their relationship with the company. Customer Lifetime Value takes into account factors such as the duration of the customer's policy, premium payments, claim history, renewal likelihood, and potential additional services or products the customer may purchase. It helps insurers assess the long-term profitability and value associated with retaining a particular customer.
#
# - Income - Customers income
#
# - Monthly Premium Auto - Amount of money the customer pays on a monthly basis as a premium for their auto insurance coverage. It represents the recurring cost that the insured person must pay to maintain their insurance policy and receive coverage for potential damages, accidents, or other covered events related to their vehicle.
#
# - Number of Open Complaints - Number of complaints the customer opened
#
# - Policy Type - There are three type of policies in car insurance (Corporate Auto, Personal Auto, and Special Auto)
#
# - Vehicle Class - Type of vehicle classes that customers have Two-Door Car, Four-Door Car SUV, Luxury SUV, Sports Car, and Luxury Car
#
# - Total Claim Amount - the sum of all claims made by the customer. It represents the total monetary value of all approved claims for incidents such as accidents, theft, vandalism, or other covered events.

# %% [markdown]
# External Resources: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %% [markdown]
# ## Challenge 1: Understanding the data
#
# In this challenge, you will use pandas to explore a given dataset. Your task is to gain a deep understanding of the data by analyzing its characteristics, dimensions, and statistical properties.

# %% [markdown]
# - Identify the dimensions of the dataset by determining the number of rows and columns it contains.
# - Determine the data types of each column and evaluate whether they are appropriate for the nature of the variable. You should also provide suggestions for fixing any incorrect data types.
# - Identify the number of unique values for each column and determine which columns appear to be categorical. You should also describe the unique values of each categorical column and the range of values for numerical columns, and give your insights.
# - Compute summary statistics such as mean, median, mode, standard deviation, and quartiles to understand the central tendency and distribution of the data for numerical columns. You should also provide your conclusions based on these summary statistics.
# - Compute summary statistics for categorical columns and providing your conclusions based on these statistics.

# %% [markdown]
# - Identify the dimensions of the dataset by determining the number of rows and columns it contains.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
data_set = pd.read_csv(url)
data_set.info()
rows, columns = data_set.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
# Customer                     1071 non-null object
# ST                           1071 non-null object
# GENDER                       954 non-null object
# Education                    1071 non-null object
# Customer Lifetime Value      1068 non-null object
# Income                       1071 non-null float64
# Monthly Premium Auto         1071 non-null float64
# Number of Open Complaints    1071 non-null object
# Policy Type                  1071 non-null object
# Vehicle Class                1071 non-null object
# Total Claim Amount           1071 non-null float64
# dtypes: float64(3), object(8)
# memory usage: 344.5+ KB
# Number of rows: 4008
# Number of columns: 11

# %%
data_set.shape
# Out:
# (4008, 11)

# %% [markdown]
# - Determine the data types of each column and evaluate whether they are appropriate for the nature of the variable. You should also provide suggestions for fixing any incorrect data types.

# %%
data_set.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
data_set.tail()
# Out:
#      Customer   ST GENDER Education Customer Lifetime Value  Income  \
# 4003      NaN  NaN    NaN       NaN                     NaN     NaN
# 4004      NaN  NaN    NaN       NaN                     NaN     NaN
# 4005      NaN  NaN    NaN       NaN                     NaN     NaN
# 4006      NaN  NaN    NaN       NaN                     NaN     NaN
# 4007      NaN  NaN    NaN       NaN                     NaN     NaN
#
#       Monthly Premium Auto Number of Open Complaints Policy Type  \
# 4003                   NaN                       NaN         NaN
# 4004                   NaN                       NaN         NaN
# 4005                   NaN                       NaN         NaN
# 4006                   NaN                       NaN         NaN
# 4007                   NaN                       NaN         NaN
#
#      Vehicle Class  Total Claim Amount
# 4003           NaN                 NaN
# 4004           NaN                 NaN
# 4005           NaN                 NaN
# ...

# %%
data_set.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
data_set["Customer Lifetime Value"]= data_set["Customer Lifetime Value"].str.replace("%", "").astype(float)

# %%
data_set["Customer"]= data_set["Customer"].astype("category")

# %%
data_set.dtypes
# Out:
# Customer                     category
# ST                             object
# GENDER                         object
# Education                      object
# Customer Lifetime Value       float64
# Income                        float64
# Monthly Premium Auto          float64
# Number of Open Complaints      object
# Policy Type                    object
# Vehicle Class                  object
# Total Claim Amount            float64
# dtype: object

# %%
data_set.head()
# Out:
#   Customer          ST GENDER             Education  Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                      NaN
# 1  QZ44356     Arizona      F              Bachelor                697953.59
# 2  AI49188      Nevada      F              Bachelor               1288743.17
# 3  WW63253  California      M              Bachelor                764586.18
# 4  GA49547  Washington      M  High School or Below                536307.65
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %% [markdown]
# - Identify the number of unique values for each column and determine which columns appear to be categorical. You should also describe the unique values of each categorical column and the range of values for numerical columns, and give your insights.

# %%
numeric_columns = list(data_set.select_dtypes(include=["float"]).columns)
object_columns = list(data_set.select_dtypes(include=["object"]).columns)
print(f"Estas son las columnas numericas: {numeric_columns}")
print(f"Estas son las columnas numericas: {object_columns}")
# Out:
# Estas son las columnas numericas: ['Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Total Claim Amount']
# Estas son las columnas numericas: ['ST', 'GENDER', 'Education', 'Number of Open Complaints', 'Policy Type', 'Vehicle Class']

# %%
unique_counts = data_set.nunique()
unique_counts
# Out:
# Customer                     1071
# ST                              8
# GENDER                          5
# Education                       6
# Customer Lifetime Value      1027
# Income                        774
# Monthly Premium Auto          132
# Number of Open Complaints       6
# Policy Type                     3
# Vehicle Class                   6
# Total Claim Amount            761
# dtype: int64

# %%
for columna in object_columns:
    print(f"{columna}:{data_set[columna].unique()}")
# Out:
# ST:['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' 'Cali' 'AZ' 'WA' nan]
# GENDER:[nan 'F' 'M' 'Femal' 'Male' 'female']
# Education:['Master' 'Bachelor' 'High School or Below' 'College' 'Bachelors' 'Doctor'
#  nan]
# Number of Open Complaints:['1/0/00' '1/2/00' '1/1/00' '1/3/00' '1/5/00' '1/4/00' nan]
# Policy Type:['Personal Auto' 'Corporate Auto' 'Special Auto' nan]
# Vehicle Class:['Four-Door Car' 'Two-Door Car' 'SUV' 'Luxury SUV' 'Sports Car'
#  'Luxury Car' nan]

# %%
for columna in numeric_columns:
    print(f"""{columna}: 
          Máximo: {data_set[columna].max()}  
          Mínimo: {data_set[columna].min()}  
          Diferencia: {data_set[columna].max()} - {data_set[columna].min()}""")
# Out:
# Customer Lifetime Value:
#           Máximo: 5816655.35
#           Mínimo: 200435.07
#           Diferencia: 5816655.35 - 200435.07
# Income:
#           Máximo: 99960.0
#           Mínimo: 0.0
#           Diferencia: 99960.0 - 0.0
# Monthly Premium Auto:
#           Máximo: 35354.0
#           Mínimo: 61.0
#           Diferencia: 35354.0 - 61.0
# Total Claim Amount:
#           Máximo: 2893.239678
#           Mínimo: 0.38210700000000003
#           Diferencia: 2893.239678 - 0.38210700000000003

# %% [markdown]
# - Compute summary statistics such as mean, median, mode, standard deviation, and quartiles to understand the central tendency and distribution of the data for numerical columns. You should also provide your conclusions based on these summary statistics.

# %%
data_set.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count             1.068000e+03   1071.000000           1071.000000
# mean              7.936903e+05  39295.701214            193.234360
# std               6.434784e+05  30469.427060           1601.190369
# min               2.004351e+05      0.000000             61.000000
# 25%               4.034080e+05  14072.000000             68.000000
# 50%               5.881742e+05  36234.000000             83.000000
# 75%               8.962872e+05  64631.000000            109.500000
# max               5.816655e+06  99960.000000          35354.000000
#
#        Total Claim Amount
# count         1071.000000
# mean           404.986909
# std            293.027260
# min              0.382107
# 25%            202.157702
# 50%            354.729129
# 75%            532.800000
# max           2893.239678

# %%
for columna in numeric_columns:
    print(f"""{columna}: 
          {data_set[columna].describe()}""")
# Out:
# Customer Lifetime Value:
#           count    1.068000e+03
# mean     7.936903e+05
# std      6.434784e+05
# min      2.004351e+05
# 25%      4.034080e+05
# 50%      5.881742e+05
# 75%      8.962872e+05
# max      5.816655e+06
# Name: Customer Lifetime Value, dtype: float64
# Income:
#           count     1071.000000
# mean     39295.701214
# std      30469.427060
# min          0.000000
# 25%      14072.000000
# 50%      36234.000000
# 75%      64631.000000
# max      99960.000000
# Name: Income, dtype: float64
# Monthly Premium Auto:
#           count     1071.000000
# mean       193.234360
# std       1601.190369
# min         61.000000
# 25%         68.000000
# 50%         83.000000
# 75%        109.500000
# max      35354.000000
# Name: Monthly Premium Auto, dtype: float64
# Total Claim Amount:
#           count    1071.000000
# mean      404.986909
# std       293.027260
# min         0.382107
# 25%       202.157702
# 50%       354.729129
# 75%       532.800000
# ...

# %%
for columna in numeric_columns:
    print(f"""{columna}: \n {data_set[columna].describe()}\n""")
# Out:
# Customer Lifetime Value:
#  count    1.068000e+03
# mean     7.936903e+05
# std      6.434784e+05
# min      2.004351e+05
# 25%      4.034080e+05
# 50%      5.881742e+05
# 75%      8.962872e+05
# max      5.816655e+06
# Name: Customer Lifetime Value, dtype: float64
#
# Income:
#  count     1071.000000
# mean     39295.701214
# std      30469.427060
# min          0.000000
# 25%      14072.000000
# 50%      36234.000000
# 75%      64631.000000
# max      99960.000000
# Name: Income, dtype: float64
#
# Monthly Premium Auto:
#  count     1071.000000
# mean       193.234360
# std       1601.190369
# min         61.000000
# 25%         68.000000
# 50%         83.000000
# 75%        109.500000
# max      35354.000000
# Name: Monthly Premium Auto, dtype: float64
#
# Total Claim Amount:
#  count    1071.000000
# mean      404.986909
# std       293.027260
# min         0.382107
# 25%       202.157702
# 50%       354.729129
# 75%       532.800000
# max      2893.239678
# ...

# %% [markdown]
# - Compute summary statistics for categorical columns and providing your conclusions based on these statistics.

# %%
for columna in object_columns:
    print(f"""{columna}: 
          {data_set[columna].describe()}""")
# Out:
# ST:
#           count       1071
# unique         8
# top       Oregon
# freq         320
# Name: ST, dtype: object
# GENDER:
#           count     954
# unique      5
# top         F
# freq      457
# Name: GENDER, dtype: object
# Education:
#           count         1071
# unique           6
# top       Bachelor
# freq           324
# Name: Education, dtype: object
# Number of Open Complaints:
#           count       1071
# unique         6
# top       1/0/00
# freq         830
# Name: Number of Open Complaints, dtype: object
# Policy Type:
#           count              1071
# unique                3
# top       Personal Auto
# freq                780
# Name: Policy Type, dtype: object
# Vehicle Class:
#           count              1071
# unique                6
# top       Four-Door Car
# freq                576
# Name: Vehicle Class, dtype: object

# %% [markdown]
# ## Challenge 2: analyzing the data

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# The marketing team wants to know the top 5 less common customer locations. Create a pandas Series object that contains the customer locations and their frequencies, and then retrieve the top 5 less common locations in ascending order.

# %%
customer_locations = data_set[["ST", "Customer"]]
customer_locations.head()
# Out:
#            ST Customer
# 0  Washington  RB50392
# 1     Arizona  QZ44356
# 2      Nevada  AI49188
# 3  California  WW63253
# 4  Washington  GA49547

# %%
customer_locations.groupby("ST").count()
# Out:
#             Customer
# ST
# AZ                25
# Arizona          186
# Cali             120
# California       211
# Nevada            98
# Oregon           320
# WA                30
# Washington        81

# %%
customer_locations.groupby("ST").count().sort_values("Customer").head(5)["Customer"]
# Out:
# ST
# AZ             25
# WA             30
# Washington     81
# Nevada         98
# Cali          120
# Name: Customer, dtype: int64

# %% [markdown]
# ### Exercise 2
#
# The sales team wants to know the total number of policies sold for each type of policy. Create a pandas Series object that contains the policy types and their total number of policies sold, and then retrieve the policy type with the highest number of policies sold.

# %% [markdown]
# *Hint:*
# - *Using value_counts() method simplifies this analysis.*
# - *Futhermore, there is a method that returns the index of the maximum value in a column or row.*

# %%
customer_policy = data_set[["Policy Type", "Customer"]]

# %%
customer_policy.groupby("Policy Type").count().sort_values("Customer")
# Out:
#                 Customer
# Policy Type
# Special Auto          57
# Corporate Auto       234
# Personal Auto        780

# %%
total_policies_by_type = data_set["Policy Type"].value_counts()
print(total_policies_by_type)

max_policy_type = total_policies_by_type.idxmax()
print(f"The policy type with the higher number of policies sold is: {max_policy_type}")
# Out:
# Personal Auto     780
# Corporate Auto    234
# Special Auto       57
# Name: Policy Type, dtype: int64
# The policy type with the higher number of policies sold is: Personal Auto

# %% [markdown]
# ### Exercise 3
#
# The sales team wants to know if customers with Personal Auto have a lower income than those with Corporate Auto. How does the average income compare between the two policy types?

# %% [markdown]
# - Use *loc* to create two dataframes: one containing only Personal Auto policies and one containing only Corporate Auto policies.
# - Calculate the average income for each policy.
# - Print the results.

# %%
data_set.groupby("Policy Type").mean()
# Out:
#                 Customer Lifetime Value        Income  Monthly Premium Auto  \
# Policy Type
# Corporate Auto            767444.110427  41390.311966            243.683761
# Personal Auto             802959.872317  38180.698718            185.701282
# Special Auto              775078.146491  45954.701754             89.210526
#
#                 Total Claim Amount
# Policy Type
# Corporate Auto          415.606539
# Personal Auto           404.820615
# Special Auto            363.666138

# %% [markdown]
# ### Bonus: Exercise 4

# %% [markdown]
# Your goal is to identify customers with a high policy claim amount.
#
# Instructions:
#
# - Review again the statistics for total claim amount to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount data.

# %% [markdown]
# *Note: When analyzing data, we often want to focus on certain groups of values to gain insights. Percentiles are a useful tool to help us define these groups. A percentile is a measure that tells us what percentage of values in a dataset are below a certain value. For example, the 75th percentile represents the value below which 75% of the data falls. Similarly, the 25th percentile represents the value below which 25% of the data falls. When we talk about the top 25%, we are referring to the values that fall above the 75th percentile, which represent the top quarter of the data. On the other hand, when we talk about the bottom 25%, we are referring to the values that fall below the 25th percentile, which represent the bottom quarter of the data. By focusing on these groups, we can identify patterns and trends that may be useful for making decisions and taking action.*
#
# *Hint: look for a method that gives you the percentile or quantile 0.75 and 0.25 for a Pandas Series.*

# %% [markdown]
# *Hint 2: check `Boolean selection according to the values of a single column` in https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9*

# %%
mayor_75 = data_set[data_set["Total Claim Amount"] >= data_set["Total Claim Amount"].quantile(0.75)]
menor_0_75= data_set[data_set["Total Claim Amount"] < data_set["Total Claim Amount"].quantile(0.75)]

# %%
print(mayor_75.describe())
print(menor_0_75.describe())
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count             2.730000e+02    273.000000            273.000000
# mean              9.183794e+05  24106.545788            163.000000
# std               6.582582e+05  27542.717560            613.645376
# min               2.287597e+05      0.000000             63.000000
# 25%               4.747735e+05      0.000000             99.000000
# 50%               7.859415e+05  18846.000000            113.000000
# 75%               1.065688e+06  44897.000000            133.000000
# max               4.022401e+06  99316.000000          10202.000000
#
#        Total Claim Amount
# count          273.000000
# mean           774.005353
# std            291.304731
# min            532.800000
# 25%            595.200000
# 50%            673.342650
# 75%            844.481918
# max           2893.239678
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# ...

# %%
for c in mayor_75:
    print(mayor_75[c].value_counts(normalize=True)*100)
# Out:
# ZZ97035    0.3663
# ON59472    0.3663
# OT52034    0.3663
# OT47603    0.3663
# TS11219    0.3663
# TS19868    0.3663
# TT82373    0.3663
# TU92578    0.3663
# TV25678    0.3663
# TV82603    0.3663
# EM29359    0.3663
# EK91340    0.3663
# TZ98966    0.3663
# JA41698    0.3663
# JB50798    0.3663
# JC11405    0.3663
# UA84837    0.3663
# EI85244    0.3663
# ON73702    0.3663
# IW54795    0.3663
# TQ13499    0.3663
# IU47468    0.3663
# EZ30498    0.3663
# FB23788    0.3663
# TC88986    0.3663
# IN17648    0.3663
# TD10493    0.3663
# TE13577    0.3663
# TE35785    0.3663
# EZ50606    0.3663
#             ...
# PY70169    0.0000
# QA87025    0.0000
# QS75550    0.0000
# QB70027    0.0000
# QR87004    0.0000
# QR45101    0.0000
# QR15857    0.0000
# QQ39596    0.0000
# QP84605    0.0000
# QP65569    0.0000
# QO65264    0.0000
# QN65180    0.0000
# QN10888    0.0000
# QL93655    0.0000
# QL77686    0.0000
# QL59704    0.0000
# QK46697    0.0000
# QJ40732    0.0000
# QH48047    0.0000
# ...

# %%
for c in menor_0_75:
    print(menor_0_75[c].value_counts(normalize=True)*100)
# Out:
# NN99001    0.125313
# JX76668    0.125313
# KP72427    0.125313
# KP34198    0.125313
# KP18988    0.125313
# KO46064    0.125313
# KO26461    0.125313
# KN21017    0.125313
# KN20603    0.125313
# KM33477    0.125313
# KL98495    0.125313
# KL57176    0.125313
# KL43114    0.125313
# KJ86296    0.125313
# KJ31611    0.125313
# KI75855    0.125313
# KI19439    0.125313
# KH64733    0.125313
# KH48895    0.125313
# KH24214    0.125313
# KF75098    0.125313
# KC17170    0.125313
# KB72438    0.125313
# KA89683    0.125313
# JZ61422    0.125313
# JY90595    0.125313
# JY27336    0.125313
# KQ65521    0.125313
# KR43119    0.125313
# KU29408    0.125313
#              ...
# MB51200    0.000000
# MC83487    0.000000
# GK71720    0.000000
# US89481    0.000000
# LU89008    0.000000
# RR77985    0.000000
# RS24501    0.000000
# LP84436    0.000000
# GO77248    0.000000
# UY18770    0.000000
# VE89726    0.000000
# RG30482    0.000000
# VO26340    0.000000
# MO56878    0.000000
# ...
